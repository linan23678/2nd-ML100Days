# %% [markdown]
# # 作業重點
#
# 使用function y=(x+5)² 來練習學習率( leanrning rate ) 調整所造成的影響

# %% [markdown]
# # 作業目標:
#     請嘗試使用不同的組合驗證 learning rate 對所需 iteration 的影響
#     lr = [0.1, 0.0001]
#     主要驗證 Lr 對於grandient 收斂的速度

# %%
cur_x = 3 # The algorithm starts at x=3
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 10000 # maximum number of iterations
df = lambda x: 2*(x+5) #Gradient of our function

# %%
lr = 0.1
previous_step_size = 2
iteratuin_counter = 0

iters_history = [iteratuin_counter]
x_history = [cur_x]

while previous_step_size > precision and iteratuin_counter <max_iters:
    prev_x = cur_x
    cur_x = cur_x - lr * df(prev_x)
    previous_step_size = abs(cur_x-prev_x)
    iteratuin_counter = iteratuin_counter + 1
    print("Iteration",iteratuin_counter,"\nX value is",cur_x,'Step_size',previous_step_size) #Print iterations

 # Store parameters for plotting
    iters_history.append(iteratuin_counter)
    x_history.append(cur_x)
# Out:
# Iteration 1
# X value is -0.9040000000000001 Step_size 1.0239999999999998
# Iteration 2
# X value is -1.7232000000000003 Step_size 0.8192000000000002
# Iteration 3
# X value is -2.3785600000000002 Step_size 0.6553599999999999
# Iteration 4
# X value is -2.902848 Step_size 0.5242879999999999
# Iteration 5
# X value is -3.3222784 Step_size 0.4194304
# Iteration 6
# X value is -3.65782272 Step_size 0.3355443199999999
# Iteration 7
# X value is -3.926258176 Step_size 0.2684354560000002
# Iteration 8
# X value is -4.1410065408 Step_size 0.21474836480000015
# Iteration 9
# X value is -4.312805232640001 Step_size 0.1717986918400003
# Iteration 10
# X value is -4.450244186112 Step_size 0.13743895347199953
# Iteration 11
# X value is -4.5601953488896 Step_size 0.10995116277759998
# Iteration 12
# X value is -4.64815627911168 Step_size 0.08796093022207963
# Iteration 13
# X value is -4.718525023289343 Step_size 0.0703687441776637
# Iteration 14
# ...

# %%
print("Totally iteations: ", iteratuin_counter)
print("The local minimum occurs at", cur_x)
# Out:
# Totally iteations:  64
# The local minimum occurs at -4.999996786123911

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(iters_history,x_history,'o',color = 'b',ms=3,lw=1.5)
plt.xlabel(r'$iters$',fontsize=16)
plt.ylabel(r'$X$',fontsize=16)
plt.show()

# %% [markdown]
# # lr = 0.001

# %%
cur_x = 3 # The algorithm starts at x=3
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 10000 # maximum number of iterations
df = lambda x: 2*(x+5) #Gradient of our function 
lr = 0.001
previous_step_size = 2
iteratuin_counter = 0

iters_history = [iteratuin_counter]
x_history = [cur_x]

# %%
while previous_step_size > precision and iteratuin_counter <max_iters:
    prev_x = cur_x
    cur_x = cur_x - lr * df(prev_x)
    previous_step_size = abs(cur_x-prev_x)
    iteratuin_counter = iteratuin_counter + 1
    print("Iteration",iteratuin_counter,"\nX value is",cur_x,'Step_size',previous_step_size) #Print iterations

 # Store parameters for plotting
    iters_history.append(iteratuin_counter)
    x_history.append(cur_x)
# Out:
# Iteration 1
# X value is 2.984 Step_size 0.016000000000000014
# Iteration 2
# X value is 2.968032 Step_size 0.015967999999999982
# Iteration 3
# X value is 2.952095936 Step_size 0.015936063999999917
# Iteration 4
# X value is 2.936191744128 Step_size 0.015904191871999984
# Iteration 5
# X value is 2.920319360639744 Step_size 0.015872383488256148
# Iteration 6
# X value is 2.9044787219184647 Step_size 0.015840638721279277
# Iteration 7
# X value is 2.8886697644746278 Step_size 0.015808957443836924
# Iteration 8
# X value is 2.8728924249456784 Step_size 0.01577733952894933
# Iteration 9
# X value is 2.8571466400957872 Step_size 0.015745784849891198
# Iteration 10
# X value is 2.8414323468155955 Step_size 0.015714293280191693
# Iteration 11
# X value is 2.825749482121964 Step_size 0.015682864693631338
# Iteration 12
# X value is 2.8100979831577204 Step_size 0.015651498964243782
# Iteration 13
# X value is 2.794477787191405 Step_size 0.015620195966315364
# Iteration 14
# ...

# %%
print("Totally iteations: ", iteratuin_counter)
print("The local minimum occurs at", cur_x)
# Out:
# Totally iteations:  4837
# The local minimum occurs at -4.999501668667748

# %%
plt.plot(iters_history,x_history,'o',color = 'r',ms=3,lw=1.5)
plt.xlabel(r'$iters$',fontsize=16)
plt.ylabel(r'$X$',fontsize=16)
plt.show()
